# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descr = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descr})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | dingle
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | buenavista
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | mandalgovi
# Processing Record 9 of Set 1 | buluang
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | roald
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | vanimo
# Processing Record 16 of Set 1 | bichura
# Processing Record 17 of Set 1 | san patricio
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | cidreira
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | chistogorskiy
# Processing Record 24 of Set 1 | katangli
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | qui nhon
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | port macquarie
# Processing Record 34 of Set 1 | nouadhibou
# Processing Record 35 of Set 1 | merzifon
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | umea
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | ocos
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | xining
# Processing Record 43 of Set 1 | mehamn
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | manta
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | oranjemund
# Processing Record 49 of Set 1 | rockhampton
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | quang ngai
# Processing Record 3 of Set 2 | mogeiro
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | okha
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | kysyl-syr
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | pingliang
# Processing Record 15 of Set 2 | havre-saint-pierre
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | izhma
# Processing Record 18 of Set 2 | alpena
# Processing Record 19 of Set 2 | arman
# Processing Record 20 of Set 2 | tiarei
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | gimli
# Processing Record 24 of Set 2 | adrar
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | curillo
# Processing Record 28 of Set 2 | whitehorse
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | haubourdin
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | gizo
# Processing Record 33 of Set 2 | egvekinot
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | hualmay
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | klaksvik
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | vestmanna
# Processing Record 40 of Set 2 | valley city
# Processing Record 41 of Set 2 | linares
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | tucuman
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | pampas
# Processing Record 46 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 47 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 2 | saldanha
# Processing Record 49 of Set 2 | mount gambier
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | pirojpur
# Processing Record 3 of Set 3 | urusha
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | tura
# Processing Record 10 of Set 3 | kungurtug
# Processing Record 11 of Set 3 | walvis bay
# Processing Record 12 of Set 3 | dunmore town
# Processing Record 13 of Set 3 | high level
# Processing Record 14 of Set 3 | laizhou
# Processing Record 15 of Set 3 | yala
# Processing Record 16 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | wanning
# Processing Record 20 of Set 3 | bambous virieux
# Processing Record 21 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 3 | constitucion
# Processing Record 23 of Set 3 | katsuura
# Processing Record 24 of Set 3 | kununurra
# Processing Record 25 of Set 3 | watertown
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | saint george
# Processing Record 28 of Set 3 | santa rosa
# Processing Record 29 of Set 3 | tiznit
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | narasannapeta
# Processing Record 32 of Set 3 | lasa
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 3 | svetlogorsk
# Processing Record 36 of Set 3 | malpe
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | altonia
# City not found. Skipping...
# Processing Record 39 of Set 3 | maple creek
# Processing Record 40 of Set 3 | banda aceh
# Processing Record 41 of Set 3 | ostrovskoye
# Processing Record 42 of Set 3 | nemuro
# Processing Record 43 of Set 3 | krasnyy chikoy
# Processing Record 44 of Set 3 | kurumkan
# Processing Record 45 of Set 3 | la ronge
# Processing Record 46 of Set 3 | vanavara
# Processing Record 47 of Set 3 | vila
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | erdenet
# Processing Record 50 of Set 3 | te anau
# Processing Record 1 of Set 4 | sao filipe
# Processing Record 2 of Set 4 | aksarka
# Processing Record 3 of Set 4 | kuytun
# Processing Record 4 of Set 4 | bintulu
# Processing Record 5 of Set 4 | zonguldak
# Processing Record 6 of Set 4 | lorengau
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | mendeleyevo
# Processing Record 9 of Set 4 | bantou
# Processing Record 10 of Set 4 | auki
# Processing Record 11 of Set 4 | juba
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | tanout
# Processing Record 15 of Set 4 | korla
# Processing Record 16 of Set 4 | penticton
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | barra do corda
# Processing Record 19 of Set 4 | mbalmayo
# Processing Record 20 of Set 4 | dudinka
# Processing Record 21 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 4 | west wendover
# Processing Record 23 of Set 4 | tessalit
# Processing Record 24 of Set 4 | qeshm
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | coruripe
# Processing Record 27 of Set 4 | bac lieu
# Processing Record 28 of Set 4 | chokwe
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 31 of Set 4 | avarua
# Processing Record 32 of Set 4 | moerai
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | talcahuano
# Processing Record 35 of Set 4 | tokmak
# Processing Record 36 of Set 4 | quelimane
# Processing Record 37 of Set 4 | nara
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | dawei
# Processing Record 41 of Set 4 | kirakira
# Processing Record 42 of Set 4 | moss point
# Processing Record 43 of Set 4 | pacific grove
# Processing Record 44 of Set 4 | saint-felicien
# Processing Record 45 of Set 4 | nantucket
# Processing Record 46 of Set 4 | acapulco
# Processing Record 47 of Set 4 | gornyy
# Processing Record 48 of Set 4 | tasiilaq
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | krasnoarmeysk
# Processing Record 1 of Set 5 | rawson
# Processing Record 2 of Set 5 | berbera
# Processing Record 3 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 5 | tornio
# Processing Record 5 of Set 5 | vagamo
# Processing Record 6 of Set 5 | parita
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | canandaigua
# Processing Record 9 of Set 5 | kelowna
# Processing Record 10 of Set 5 | murbad
# Processing Record 11 of Set 5 | mangai
# Processing Record 12 of Set 5 | houma
# Processing Record 13 of Set 5 | ayan
# Processing Record 14 of Set 5 | kalawit
# Processing Record 15 of Set 5 | tshikapa
# Processing Record 16 of Set 5 | mareeba
# Processing Record 17 of Set 5 | chute-aux-outardes
# Processing Record 18 of Set 5 | kichera
# Processing Record 19 of Set 5 | kolda
# Processing Record 20 of Set 5 | areia
# Processing Record 21 of Set 5 | hobyo
# Processing Record 22 of Set 5 | port lincoln
# Processing Record 23 of Set 5 | vernon
# Processing Record 24 of Set 5 | port hardy
# Processing Record 25 of Set 5 | asyut
# Processing Record 26 of Set 5 | lokosovo
# Processing Record 27 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 5 | tual
# Processing Record 29 of Set 5 | xapuri
# Processing Record 30 of Set 5 | shalya
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | kopyevo
# City not found. Skipping...
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | luwuk
# Processing Record 36 of Set 5 | rio gallegos
# Processing Record 37 of Set 5 | marzuq
# Processing Record 38 of Set 5 | meadow lake
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | tautira
# Processing Record 41 of Set 5 | bagdarin
# Processing Record 42 of Set 5 | vila franca do campo
# Processing Record 43 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 5 | taoudenni
# Processing Record 46 of Set 5 | toamasina
# Processing Record 47 of Set 5 | barre
# Processing Record 48 of Set 5 | avera
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 5 | aktash
# Processing Record 1 of Set 6 | port blair
# Processing Record 2 of Set 6 | cabinda
# Processing Record 3 of Set 6 | pangnirtung
# Processing Record 4 of Set 6 | vyartsilya
# Processing Record 5 of Set 6 | piterka
# Processing Record 6 of Set 6 | kieta
# Processing Record 7 of Set 6 | nome
# Processing Record 8 of Set 6 | fort-shevchenko
# Processing Record 9 of Set 6 | carbonia
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | linxia
# Processing Record 12 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 13 of Set 6 | batemans bay
# Processing Record 14 of Set 6 | villa del rosario
# Processing Record 15 of Set 6 | luena
# Processing Record 16 of Set 6 | nizhniye sergi
# Processing Record 17 of Set 6 | mahebourg
# Processing Record 18 of Set 6 | zhanaozen
# Processing Record 19 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 20 of Set 6 | thompson
# Processing Record 21 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 6 | mana
# Processing Record 23 of Set 6 | caceres
# Processing Record 24 of Set 6 | muros
# Processing Record 25 of Set 6 | kaitangata
# Processing Record 26 of Set 6 | hovd
# Processing Record 27 of Set 6 | longyearbyen
# Processing Record 28 of Set 6 | ambilobe
# Processing Record 29 of Set 6 | saskylakh
# Processing Record 30 of Set 6 | college
# Processing Record 31 of Set 6 | deputatskiy
# Processing Record 32 of Set 6 | makakilo city
# Processing Record 33 of Set 6 | esperance
# Processing Record 34 of Set 6 | hilpoltstein
# Processing Record 35 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 6 | jabinyanah
# Processing Record 37 of Set 6 | marsala
# Processing Record 38 of Set 6 | durusu
# Processing Record 39 of Set 6 | mananara
# Processing Record 40 of Set 6 | airai
# Processing Record 41 of Set 6 | olinda
# Processing Record 42 of Set 6 | upernavik
# Processing Record 43 of Set 6 | aden
# Processing Record 44 of Set 6 | marsa matruh
# Processing Record 45 of Set 6 | kaspiyskiy
# Processing Record 46 of Set 6 | port-gentil
# Processing Record 47 of Set 6 | basco
# Processing Record 48 of Set 6 | tocopilla
# Processing Record 49 of Set 6 | berlevag
# Processing Record 50 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | cabo san lucas
# Processing Record 2 of Set 7 | jawhar
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | koutsouras
# Processing Record 5 of Set 7 | yar-sale
# Processing Record 6 of Set 7 | ouallam
# Processing Record 7 of Set 7 | puerto cabezas
# Processing Record 8 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 7 | rosario
# Processing Record 10 of Set 7 | moose factory
# Processing Record 11 of Set 7 | miri
# Processing Record 12 of Set 7 | camacha
# Processing Record 13 of Set 7 | araouane
# Processing Record 14 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 7 | pryozerne
# Processing Record 16 of Set 7 | bilibino
# Processing Record 17 of Set 7 | hami
# Processing Record 18 of Set 7 | ombessa
# Processing Record 19 of Set 7 | latehar
# Processing Record 20 of Set 7 | shingu
# Processing Record 21 of Set 7 | mayo
# Processing Record 22 of Set 7 | dong hoi
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | isangel
# Processing Record 25 of Set 7 | mumford
# Processing Record 26 of Set 7 | hervey bay
# Processing Record 27 of Set 7 | portland
# Processing Record 28 of Set 7 | montrose
# Processing Record 29 of Set 7 | barcelos
# Processing Record 30 of Set 7 | el jicaro
# Processing Record 31 of Set 7 | samarai
# Processing Record 32 of Set 7 | dawlatabad
# Processing Record 33 of Set 7 | salas
# Processing Record 34 of Set 7 | muroto
# Processing Record 35 of Set 7 | coatesville
# Processing Record 36 of Set 7 | coihaique
# Processing Record 37 of Set 7 | strausberg
# Processing Record 38 of Set 7 | fort frances
# Processing Record 39 of Set 7 | marawi
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | luderitz
# Processing Record 42 of Set 7 | padang
# Processing Record 43 of Set 7 | kirchhundem
# Processing Record 44 of Set 7 | maningrida
# Processing Record 45 of Set 7 | tibu
# Processing Record 46 of Set 7 | sinait
# Processing Record 47 of Set 7 | waingapu
# Processing Record 48 of Set 7 | odweyne
# Processing Record 49 of Set 7 | piranshahr
# Processing Record 50 of Set 7 | wucheng
# Processing Record 1 of Set 8 | erzin
# Processing Record 2 of Set 8 | guymon
# Processing Record 3 of Set 8 | bitung
# Processing Record 4 of Set 8 | rapid valley
# Processing Record 5 of Set 8 | dalianwan
# Processing Record 6 of Set 8 | sorland
# Processing Record 7 of Set 8 | nanortalik
# Processing Record 8 of Set 8 | bayevo
# Processing Record 9 of Set 8 | brainerd
# Processing Record 10 of Set 8 | puerto leguizamo
# Processing Record 11 of Set 8 | aksu
# Processing Record 12 of Set 8 | marienburg
# Processing Record 13 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 8 | grants pass
# Processing Record 15 of Set 8 | villa carlos paz
# Processing Record 16 of Set 8 | souillac
# Processing Record 17 of Set 8 | kalakamati
# Processing Record 18 of Set 8 | san juan
# Processing Record 19 of Set 8 | sistranda
# Processing Record 20 of Set 8 | cayenne
# Processing Record 21 of Set 8 | dubbo
# Processing Record 22 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 23 of Set 8 | santa cruz
# Processing Record 24 of Set 8 | fonte boa
# Processing Record 25 of Set 8 | lipany
# Processing Record 26 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 8 | tumaco
# Processing Record 28 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 8 | vardo
# Processing Record 30 of Set 8 | belaya gora
# Processing Record 31 of Set 8 | timbakion
# City not found. Skipping...
# Processing Record 32 of Set 8 | juegang
# Processing Record 33 of Set 8 | morgan city
# Processing Record 34 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 8 | kachiry
# Processing Record 36 of Set 8 | codrington
# Processing Record 37 of Set 8 | asau
# Processing Record 38 of Set 8 | iquitos
# Processing Record 39 of Set 8 | guanajay
# Processing Record 40 of Set 8 | fairbanks
# Processing Record 41 of Set 8 | turukhansk
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | kokopo
# Processing Record 44 of Set 8 | grindavik
# Processing Record 45 of Set 8 | namatanai
# Processing Record 46 of Set 8 | pedernales
# Processing Record 47 of Set 8 | osa
# Processing Record 48 of Set 8 | kavieng
# Processing Record 49 of Set 8 | saint-pierre
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | deqing
# Processing Record 2 of Set 9 | varhaug
# Processing Record 3 of Set 9 | talara
# Processing Record 4 of Set 9 | koslan
# Processing Record 5 of Set 9 | srednekolymsk
# Processing Record 6 of Set 9 | bichena
# Processing Record 7 of Set 9 | guerrero negro
# Processing Record 8 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 9 | sesheke
# Processing Record 10 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 9 | vagay
# Processing Record 12 of Set 9 | bam
# Processing Record 13 of Set 9 | dalvik
# Processing Record 14 of Set 9 | akola
# Processing Record 15 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 16 of Set 9 | santarem
# Processing Record 17 of Set 9 | itoman
# Processing Record 18 of Set 9 | kushima
# Processing Record 19 of Set 9 | olafsvik
# Processing Record 20 of Set 9 | mariel
# Processing Record 21 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 9 | zhigansk
# Processing Record 23 of Set 9 | suez
# Processing Record 24 of Set 9 | ajaccio
# Processing Record 25 of Set 9 | tondano
# Processing Record 26 of Set 9 | esfarayen
# Processing Record 27 of Set 9 | mount isa
# Processing Record 28 of Set 9 | brejo
# Processing Record 29 of Set 9 | suntar
# Processing Record 30 of Set 9 | hammerfest
# Processing Record 31 of Set 9 | kattivakkam
# Processing Record 32 of Set 9 | lobito
# Processing Record 33 of Set 9 | upington
# Processing Record 34 of Set 9 | tokur
# Processing Record 35 of Set 9 | oktyabrskoye
# Processing Record 36 of Set 9 | hit
# Processing Record 37 of Set 9 | dakar
# Processing Record 38 of Set 9 | sabang
# Processing Record 39 of Set 9 | bilma
# Processing Record 40 of Set 9 | bojnurd
# Processing Record 41 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 42 of Set 9 | kushmurun
# Processing Record 43 of Set 9 | milkovo
# Processing Record 44 of Set 9 | acari
# Processing Record 45 of Set 9 | taltal
# Processing Record 46 of Set 9 | sioux lookout
# Processing Record 47 of Set 9 | sovetskiy
# Processing Record 48 of Set 9 | paracelis
# Processing Record 49 of Set 9 | ust-kuyga
# Processing Record 50 of Set 9 | ilulissat
# Processing Record 1 of Set 10 | preobrazheniye
# Processing Record 2 of Set 10 | biltine
# Processing Record 3 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 10 | morondava
# Processing Record 5 of Set 10 | rochegda
# Processing Record 6 of Set 10 | tateyama
# Processing Record 7 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | xichang
# Processing Record 10 of Set 10 | catia la mar
# Processing Record 11 of Set 10 | nelson bay
# Processing Record 12 of Set 10 | spanaway
# Processing Record 13 of Set 10 | ekibastuz
# Processing Record 14 of Set 10 | boulder city
# Processing Record 15 of Set 10 | matadi
# Processing Record 16 of Set 10 | asekeyevo
# Processing Record 17 of Set 10 | alasehir
# Processing Record 18 of Set 10 | abu samrah
# Processing Record 19 of Set 10 | bay roberts
# Processing Record 20 of Set 10 | kincardine
# Processing Record 21 of Set 10 | iguape
# Processing Record 22 of Set 10 | kisaran
# Processing Record 23 of Set 10 | lubango
# Processing Record 24 of Set 10 | hoghilag
# Processing Record 25 of Set 10 | tarata
# Processing Record 26 of Set 10 | fairfield
# Processing Record 27 of Set 10 | awbari
# Processing Record 28 of Set 10 | gao
# Processing Record 29 of Set 10 | katete
# Processing Record 30 of Set 10 | hasaki
# Processing Record 31 of Set 10 | narsaq
# Processing Record 32 of Set 10 | los zacatones
# Processing Record 33 of Set 10 | kibre mengist
# Processing Record 34 of Set 10 | bluefields
# Processing Record 35 of Set 10 | leh
# Processing Record 36 of Set 10 | homer
# Processing Record 37 of Set 10 | north bend
# Processing Record 38 of Set 10 | abashiri
# Processing Record 39 of Set 10 | whitianga
# Processing Record 40 of Set 10 | komsomolskiy
# Processing Record 41 of Set 10 | norwich
# Processing Record 42 of Set 10 | mae ramat
# Processing Record 43 of Set 10 | husavik
# Processing Record 44 of Set 10 | starosubkhangulovo
# Processing Record 45 of Set 10 | chimore
# Processing Record 46 of Set 10 | kaeo
# Processing Record 47 of Set 10 | golden
# Processing Record 48 of Set 10 | plettenberg bay
# Processing Record 49 of Set 10 | jaciara
# Processing Record 50 of Set 10 | suzu
# City not found. Skipping...
# Processing Record 1 of Set 11 | dinghai
# Processing Record 2 of Set 11 | poum
# Processing Record 3 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 11 | sharjah
# Processing Record 5 of Set 11 | richards bay
# Processing Record 6 of Set 11 | tabas
# Processing Record 7 of Set 11 | dongning
# Processing Record 8 of Set 11 | york
# Processing Record 9 of Set 11 | terrace
# Processing Record 10 of Set 11 | kitaibaraki
# Processing Record 11 of Set 11 | kutum
# Processing Record 12 of Set 11 | aswan
# Processing Record 13 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 11 | westport
# Processing Record 15 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 16 of Set 11 | big rapids
# Processing Record 17 of Set 11 | gubbi
# Processing Record 18 of Set 11 | lima
# Processing Record 19 of Set 11 | malartic
# Processing Record 20 of Set 11 | manacapuru
# Processing Record 21 of Set 11 | bischwiller
# Processing Record 22 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 11 | miraflores
# Processing Record 24 of Set 11 | pemberton
# Processing Record 25 of Set 11 | hirado
# Processing Record 26 of Set 11 | morant bay
# Processing Record 27 of Set 11 | imeni poliny osipenko
# Processing Record 28 of Set 11 | burica
# City not found. Skipping...
# Processing Record 29 of Set 11 | vestmannaeyjar
# Processing Record 30 of Set 11 | san ramon de la nueva oran
# Processing Record 31 of Set 11 | harper
# Processing Record 32 of Set 11 | jalu
# Processing Record 33 of Set 11 | terrell
# Processing Record 34 of Set 11 | primore
# City not found. Skipping...
# Processing Record 35 of Set 11 | kholm
# Processing Record 36 of Set 11 | lao cai
# Processing Record 37 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 11 | toppenish
# Processing Record 39 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 40 of Set 11 | el vigia
# Processing Record 41 of Set 11 | kultuk
# Processing Record 42 of Set 11 | horki
# Processing Record 43 of Set 11 | segou
# Processing Record 44 of Set 11 | ahipara
# Processing Record 45 of Set 11 | taclobo
# Processing Record 46 of Set 11 | kenitra
# Processing Record 47 of Set 11 | siteki
# Processing Record 48 of Set 11 | hambantota
# Processing Record 49 of Set 11 | gravdal
# Processing Record 50 of Set 11 | cambuga
# Processing Record 1 of Set 12 | pontes e lacerda
# Processing Record 2 of Set 12 | lagoa
# Processing Record 3 of Set 12 | myitkyina
# Processing Record 4 of Set 12 | cessnock
# Processing Record 5 of Set 12 | garowe
# Processing Record 6 of Set 12 | grafton
# Processing Record 7 of Set 12 | yuci
# Processing Record 8 of Set 12 | lavrentiya
# Processing Record 9 of Set 12 | cockburn town
# Processing Record 10 of Set 12 | asfi
# Processing Record 11 of Set 12 | jilib
# Processing Record 12 of Set 12 | coquimbo
# Processing Record 13 of Set 12 | kargasok
# Processing Record 14 of Set 12 | vostok
# Processing Record 15 of Set 12 | esmeraldas
# Processing Record 16 of Set 12 | nador
# Processing Record 17 of Set 12 | kalmunai
# Processing Record 18 of Set 12 | matara
# Processing Record 19 of Set 12 | smithers
# Processing Record 20 of Set 12 | aklavik
# Processing Record 21 of Set 12 | beidao
# Processing Record 22 of Set 12 | uruzgan
# Processing Record 23 of Set 12 | ancona
# Processing Record 24 of Set 12 | mezen
# Processing Record 25 of Set 12 | trinidad
# Processing Record 26 of Set 12 | jinchang
# Processing Record 27 of Set 12 | ndele
# Processing Record 28 of Set 12 | trairi
# Processing Record 29 of Set 12 | flinders
# Processing Record 30 of Set 12 | mon
# Processing Record 31 of Set 12 | mehran
# Processing Record 32 of Set 12 | sann
# Processing Record 33 of Set 12 | coari
# Processing Record 34 of Set 12 | angoche
# Processing Record 35 of Set 12 | itarare
# Processing Record 36 of Set 12 | stamford
# Processing Record 37 of Set 12 | coos bay
# Processing Record 38 of Set 12 | beloha
# Processing Record 39 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 12 | ixtapa
# Processing Record 42 of Set 12 | mendoza
# Processing Record 43 of Set 12 | sangar
# Processing Record 44 of Set 12 | nicoya
# Processing Record 45 of Set 12 | am timan
# Processing Record 46 of Set 12 | nisia floresta
# Processing Record 47 of Set 12 | magalia
# Processing Record 48 of Set 12 | anadyr
# Processing Record 49 of Set 12 | borna
# Processing Record 50 of Set 12 | sogne
# Processing Record 1 of Set 13 | lekoni
# Processing Record 2 of Set 13 | margate
# Processing Record 3 of Set 13 | kavaratti
# Processing Record 4 of Set 13 | tay ninh
# Processing Record 5 of Set 13 | de aar
# Processing Record 6 of Set 13 | beboto
# Processing Record 7 of Set 13 | gebre guracha
# Processing Record 8 of Set 13 | darnah
# Processing Record 9 of Set 13 | matagami
# Processing Record 10 of Set 13 | porto santo
# Processing Record 11 of Set 13 | biskamzha
# Processing Record 12 of Set 13 | waddan
# Processing Record 13 of Set 13 | santo antonio do ica
# Processing Record 14 of Set 13 | hobbs
# Processing Record 15 of Set 13 | natal
# Processing Record 16 of Set 13 | miranda de ebro
# Processing Record 17 of Set 13 | vostan
# Processing Record 18 of Set 13 | biloela
# Processing Record 19 of Set 13 | mabaruma
# Processing Record 20 of Set 13 | sosnovskiy
# City not found. Skipping...
# Processing Record 21 of Set 13 | praya
# Processing Record 22 of Set 13 | touros
# Processing Record 23 of Set 13 | kindu
# Processing Record 24 of Set 13 | santa rita
# Processing Record 25 of Set 13 | mao
# Processing Record 26 of Set 13 | bireun
# Processing Record 27 of Set 13 | kaduy
# Processing Record 28 of Set 13 | kambove
# Processing Record 29 of Set 13 | laguna
# Processing Record 30 of Set 13 | moctezuma
# Processing Record 31 of Set 13 | goderich
# Processing Record 32 of Set 13 | surgut
# Processing Record 33 of Set 13 | killybegs
# Processing Record 34 of Set 13 | poya
# Processing Record 35 of Set 13 | buarcos
# Processing Record 36 of Set 13 | vila velha
# Processing Record 37 of Set 13 | beringovskiy
# Processing Record 38 of Set 13 | bukama
# Processing Record 39 of Set 13 | tieli
# Processing Record 40 of Set 13 | chuy
# Processing Record 41 of Set 13 | sal rei
# Processing Record 42 of Set 13 | kuznechikha
# Processing Record 43 of Set 13 | magaria
# Processing Record 44 of Set 13 | waipawa
# Processing Record 45 of Set 13 | jan kempdorp
# Processing Record 46 of Set 13 | sola
# Processing Record 47 of Set 13 | ende
# Processing Record 48 of Set 13 | jalapa
# Processing Record 49 of Set 13 | alexandria
# Processing Record 50 of Set 13 | manzil salim
# Processing Record 1 of Set 14 | marquette
# Processing Record 2 of Set 14 | sarai sidhu
# Processing Record 3 of Set 14 | boende
# Processing Record 4 of Set 14 | diu
# Processing Record 5 of Set 14 | axim
# Processing Record 6 of Set 14 | abu dhabi
# Processing Record 7 of Set 14 | jardim
# Processing Record 8 of Set 14 | puerto cortes
# City not found. Skipping...
# Processing Record 9 of Set 14 | pemangkat
# Processing Record 10 of Set 14 | nyaunglebin
# Processing Record 11 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 14 | qaqortoq
# Processing Record 13 of Set 14 | cumaral
# Processing Record 14 of Set 14 | haljala
# Processing Record 15 of Set 14 | zaragoza
# Processing Record 16 of Set 14 | ponta delgada
# Processing Record 17 of Set 14 | san rafael del sur
# Processing Record 18 of Set 14 | aonla
# Processing Record 19 of Set 14 | nizwa
# Processing Record 20 of Set 14 | azare
# Processing Record 21 of Set 14 | nuuk
# Processing Record 22 of Set 14 | pakxan
# Processing Record 23 of Set 14 | eau claire
# Processing Record 24 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 14 | tukrah
# Processing Record 26 of Set 14 | sinnamary
# Processing Record 27 of Set 14 | juneau
# Processing Record 28 of Set 14 | praia da vitoria
# Processing Record 29 of Set 14 | karakol
# Processing Record 30 of Set 14 | skibbereen
# Processing Record 31 of Set 14 | daman
# Processing Record 32 of Set 14 | grand gaube
# Processing Record 33 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 14 | okhotsk
# Processing Record 35 of Set 14 | chom bung
# City not found. Skipping...
# Processing Record 36 of Set 14 | amot
# Processing Record 37 of Set 14 | arlit
# Processing Record 38 of Set 14 | bowen
# Processing Record 39 of Set 14 | acarau
# Processing Record 40 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 41 of Set 14 | gigmoto
# Processing Record 42 of Set 14 | yuza
# Processing Record 43 of Set 14 | zhezkazgan
# Processing Record 44 of Set 14 | voh
# Processing Record 45 of Set 14 | siuna
# Processing Record 46 of Set 14 | saint-augustin
# Processing Record 47 of Set 14 | ailigandi
# Processing Record 48 of Set 14 | san quintin
# Processing Record 49 of Set 14 | pasighat
# Processing Record 50 of Set 14 | nizhnyaya maktama
# Processing Record 1 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 2 of Set 15 | paamiut
# Processing Record 3 of Set 15 | state college
# Processing Record 4 of Set 15 | paita
# Processing Record 5 of Set 15 | antibes
# Processing Record 6 of Set 15 | mogadishu
# Processing Record 7 of Set 15 | pundaguitan
# Processing Record 8 of Set 15 | merauke
# Processing Record 9 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 15 | key largo
# Processing Record 11 of Set 15 | daraitan
# Processing Record 12 of Set 15 | gat
# Processing Record 13 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 15 | otane
# Processing Record 15 of Set 15 | isla vista
# Processing Record 16 of Set 15 | macerata
# Processing Record 17 of Set 15 | noumea
# Processing Record 18 of Set 15 | sakaraha
# Processing Record 19 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 15 | baruun-urt
# Processing Record 21 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 15 | shetpe
# Processing Record 23 of Set 15 | ratnagiri
# Processing Record 24 of Set 15 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 25 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 15 | chulym
# Processing Record 27 of Set 15 | henties bay
# Processing Record 28 of Set 15 | khingansk
# Processing Record 29 of Set 15 | lukang
# Processing Record 30 of Set 15 | labrea
# Processing Record 31 of Set 15 | half moon bay
# Processing Record 32 of Set 15 | teguldet
# Processing Record 33 of Set 15 | sur
# Processing Record 34 of Set 15 | boueni
# Processing Record 35 of Set 15 | nouakchott
# Processing Record 36 of Set 15 | shirgaon
# Processing Record 37 of Set 15 | bathurst
# Processing Record 38 of Set 15 | turan
# Processing Record 39 of Set 15 | maraa
# Processing Record 40 of Set 15 | ust-tsilma
# Processing Record 41 of Set 15 | vysotsk
# Processing Record 42 of Set 15 | minas
# Processing Record 43 of Set 15 | chail
# Processing Record 44 of Set 15 | sabana de torres
# Processing Record 45 of Set 15 | isla mujeres
# Processing Record 46 of Set 15 | nacala
# Processing Record 47 of Set 15 | teya
# Processing Record 48 of Set 15 | sabha
# Processing Record 49 of Set 15 | boden
# Processing Record 50 of Set 15 | jefferson city
# Processing Record 1 of Set 16 | iquique
# Processing Record 2 of Set 16 | champerico
# Processing Record 3 of Set 16 | nehe
# Processing Record 4 of Set 16 | sanary-sur-mer
# Processing Record 5 of Set 16 | kharp
# Processing Record 6 of Set 16 | otradnoye
# Processing Record 7 of Set 16 | charters towers
# Processing Record 8 of Set 16 | broken hill
# Processing Record 9 of Set 16 | uglovskoye
# Processing Record 10 of Set 16 | raudeberg
# Processing Record 11 of Set 16 | campana
# Processing Record 12 of Set 16 | hargeysa
# Processing Record 13 of Set 16 | moba
# Processing Record 14 of Set 16 | sitia
# Processing Record 15 of Set 16 | bosaso
# Processing Record 16 of Set 16 | washington
# Processing Record 17 of Set 16 | tymovskoye
# Processing Record 18 of Set 16 | sonqor
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mataura      NZ -46.1927  168.8643     46.71        98          31
# 1      Dingle      PH  10.9995  122.6711     75.76        91          78
# 2   Jamestown      US  42.0970  -79.2353     54.84        81           1
# 3      Albany      US  42.6001  -73.9662     52.48        80          73
# 4  Buenavista      PH   8.9769  125.4089     75.65        92          73
# 5      Torbay      CA  47.6666  -52.7314     40.57        82          90
# 6  Mandalgovi      MN  45.7625  106.2708     36.55        41           0
# 7     Buluang      PH  13.3068  123.3425     75.76        91          98
# 8       Vaini      TO -21.2000 -175.2000     73.56        83          75
# 9     Ushuaia      AR -54.8000  -68.3000     58.66        44          20
#
#    Wind Speed Current Description
# 0        0.65    scattered clouds
# 1        7.36          light rain
# 2        3.00           clear sky
# 3        3.13       broken clouds
# 4        4.05       broken clouds
# 5       14.97     overcast clouds
# 6        7.23           clear sky
# 7        4.07     overcast clouds
# 8        5.75       broken clouds
# 9       17.27          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
